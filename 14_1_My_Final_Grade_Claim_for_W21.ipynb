# %% [markdown]
# <a href="https://colab.research.google.com/github/BrettonSteiner/cse380-notebooks/blob/master/14_1_My_Final_Grade_Claim_for_W21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Final Grade Claim - Winter 2021
# ## Bretton Steiner

# %% [markdown]
# ### Flowchart Image

# %% [markdown]
# ![Grade Claim Flowchart - Highlighted.png](data:image/png;base64,...)

# %% [markdown]
# ### Top Evidences

# %% [markdown]
# [Implemented classes with the same functionalites of separate functions](https://colab.research.google.com/github/BrettonSteiner/cse380-notebooks/blob/master/10_2_Ponder_and_Prove_Spanning_Trees.ipynb#scrollTo=CpVcRCttivNA). The Ponder and Prove 10 assignment only required us to write functions to solve the problems, but my team and I decided to make a couple classes which would handle most of the logic within themselves to go above and beyond.

# %% [markdown]
# [Researched and learned to make a graphviz render into a specific shape](https://colab.research.google.com/github/BrettonSteiner/cse380-notebooks/blob/master/11_3_About_The_Petersen_Graph.ipynb#scrollTo=k4g2e_b2nHvn&line=1&uniqifier=1). I made a graph look just like the Peterson graph and I shared with the class how I did it.

# %% [markdown]
# ### Evidences of Above and Beyond Behavior

# %% [markdown]
# 1. I worked with a classmate to write code that analyzes a series of Huffman Trees and prints out their compression ratios. This gave us deeper insight as to the effectiveness of Huffman Tree compression.
#
# 2. I wrote extra code to generate a ladder graph of any size I want, even though it wasn't required for Ponder and Prove 10. This helped me find a deeper understanding of how many "bars" are in a bar graph since I had to figure out an algorithm to make them.
#
# 3. I also wrote extra code to create a random graph that guaranteed having over 40 or more links if given 20 as the amount of nodes. This made the last portion of the Ponder and Prove 10 go much quicker and my teammates appreciated it.
#
# 4. I got the clique or anti-clique tests down to about 2.5 - 3 seconds in Ponder and Prove 11 while also keeping within the assignment requirements. I discovered that a clique graph would have $\frac{n(n-1)}{2}$ links where $n$ is the number of nodes in the corresponding complete graph. I figured this out on my own, but when I shared it with my teammates, I explained how it worked so they could understand it. One of my teammates even improved upon my original code! Working with others really provides an experience I couldn't get on my own!
#
# 5. I also discovered how the complete graph pattern fits into the process of making a Peterson graph through the complement of the line graph of $K_5$. I created a function that will generate all of the links of a complete graph to use in making the process more efficient.
#
# 6. I changed the pigeonhole_from_pigeon function in Ponder and Prove 12 to be able to generate the pigeonhole with any number of binary features. It was a small change, but I wanted to do it for fun. I shared my code results with my teammates and explained how it all worked.
#
# 7. As part of the undecided problem in Ponder and Prove 13, my team and I decided to dive deeper into the algorithm after we discovered what it was. One thing I was able to reason was that the algorithm would overtime become less and less efficient. This is evident by the increasing number of steps to find the next prime in the sequence. As a result, we concluded that there will likely be a point in which this algorithm will be less efficient to run than a different prime-finding algorithm. I say likely because I didn't prove when it would be less efficient or what it should be replaced with.
